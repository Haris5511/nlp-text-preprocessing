# %%
import torch

text= "I LOVE PAKISTAN AND LIKE PIZZA TO EAT"
text= text.lower()

print(text)
# Out:
# i love pakistan and like pizza to eat

# %%
text="MY NAME IS HARIS AZEEM AND I HAVE DONE RECENTLY MY BACHELOR DEGREE FROM THE UOL."
text=text.lower()
print(text)
# Out:
# my name is haris azeem and i have done recently my bachelor degree from the uol.

# %%
import re
import string
import torch

text=" I LOVE NLP !!! Visit https://google.com. MY PHONE costs iS 25000."

def clean_text(text):
    text=text.lower()
    text=re.sub(r"http\S+", "",text)
    text=re.sub(r"\d+", "",text)
    text=text.translate(
    str.maketrans("", "",string.punctuation)
    )
    text=" ".join(text.split())

    return text

print(clean_text(text))
# Out:
# i love nlp visit my phone costs is
